# %% [markdown]
# # 🎮 Hands-On: Classificação de Dados com Pandas e Scikit-Learn
#
# Bem-vindo ao nosso desafio de análise de dados! Imagine que você foi contratado por uma grande empresa do setor de videogames para analisar as vendas de jogos e ajudar a prever quais jogos têm maior chance de se tornarem best-sellers. Para isso, você usará técnicas de **tratamento, análise e classificação de dados**.
#
# Nosso objetivo é transformar um conjunto de dados brutos em insights valiosos e construir um modelo preditivo para classificar os jogos de acordo com seu potencial de vendas globais.

# %% [markdown]
# ## 🔹 Seção 1: Carregamento e Exploração dos Dados

# %%
# Importar bibliotecas essenciais
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Carregar o dataset
# Insira o código aqui

# %%
# Exibir as primeiras 10 linhas e verificar informações gerais
# Insira o código aqui

# %%
# Identificar valores ausentes
# Insira o código aqui

# %% [markdown]
# ## 🔹 Seção 2: Pré-processamento de Dados

# %%
# Remover colunas irrelevantes
# Insira o código aqui

# %%
# Tratar valores ausentes
# Insira o código aqui

# %%
# Converter colunas categóricas em numéricas
# Insira o código aqui

# %% [markdown]
# ## 🔹 Seção 3: Análise e Transformação de Dados

# %%
# Criar novas colunas derivadas
# Insira o código aqui

# %%
# Normalizar ou padronizar os valores numéricos
# Insira o código aqui

# %%
# Criar gráficos exploratórios
# Insira o código aqui

# %%
# Identificar correlações entre variáveis
# Insira o código aqui

# %% [markdown]
# ## 🔹 Seção 4: Preparação para a Classificação

# %%
# Criar a variável alvo High_Sales
# Insira o código aqui

# %%
# Dividir os dados em treino e teste
# Insira o código aqui

# %%
# Selecionar um modelo de classificação
# Insira o código aqui

# %% [markdown]
# ## 🔹 Seção 5: Aplicação do Modelo e Avaliação

# %%
# Treinar o modelo e realizar previsões
# Insira o código aqui

# %%
# Avaliar o desempenho do modelo
# Insira o código aqui

# %%
# Testar diferentes hiperparâmetros
# Insira o código aqui

# %% [markdown]
# 🎯 **Desafio final:** Com os resultados obtidos, como você recomendaria que a empresa utilizasse esses insights para prever o sucesso de novos jogos? Quais melhorias poderiam ser feitas no modelo?
